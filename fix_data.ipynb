# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('data/BaseDatosHistorica_Tronadura_Hackathon.xlsx', header=2)

# %%
"""
Eliminar filas donde todos son nans
Se eliminan 42 filas
"""
df = df.dropna(how='all')

# %%
def split_by_x(x):
    if 'x' in x:
        return x.split('x')
    else:
        return x.split('X')

# %%
def split_by_dash(x):
    if x == '-1':
        return [x,x]
    else:
        return x.split('-')

# %%
df['B'] = df['BxS'].apply(lambda x: split_by_x(x)[0])
df['S'] =  df['BxS'].apply(lambda x: split_by_x(x)[1])
df['tiempo_1'] = df['Tiempo entre Pozos Filas ms'].fillna('-1').apply(lambda x: split_by_dash(x)[0])
df['tiempo_2'] = df['Tiempo entre Pozos Filas ms'].fillna('-1').apply(lambda x: split_by_dash(x)[1])

# %%
df['tiempo_1'] = df['tiempo_1'].replace({'-1':None})
df['tiempo_2'] = df['tiempo_2'].replace({'-1':None})

# %%
df.dtypes
# Out:
# Fase                            object
# Banco                          float64
# Tipo de tronadura               object
# Tipo Material                   object
# M                               object
# Dominio Estructural             object
# Diámetro                       float64
# BxS                             object
# Tiempo entre Pozos Filas ms     object
# Fc                             float64
# Tipo Explosivo                  object
# P10                            float64
# P20                             object
# P30                             object
# P40                            float64
# P50                             object
# P60                            float64
# P70                             object
# P80                            float64
# P90                            float64
# P100                           float64
# Este                            object
# Norte                           object
# Cota                           float64
# B                               object
# S                               object
# tiempo_1                        object
# tiempo_2                        object
# dtype: object

# %%
"""
Fix types
<in> : P20, P30, P50, P70
"""
def take_in_out(x):
    x = str(x)
    if '..' in x:
        x = x.replace('..','.')
    elif ' in' in x:
        x = x.replace(' in','')
    return x
    
df['P20'] = df['P20'].apply(lambda x: take_in_out(x))
df['P30'] = df['P30'].apply(lambda x: take_in_out(x))
df['P50'] = df['P50'].apply(lambda x: take_in_out(x))
df['P70'] = df['P70'].apply(lambda x: take_in_out(x))

df['P20'] = pd.to_numeric(df['P20'])
df['P30'] = pd.to_numeric(df['P30'])
df['P50'] = pd.to_numeric(df['P50'])
df['P70'] = pd.to_numeric(df['P70'])
df['B'] = pd.to_numeric(df['B'])
df['S'] = pd.to_numeric(df['S'])
df['tiempo_1'] = pd.to_numeric(df['tiempo_1'])
df['tiempo_2'] = pd.to_numeric(df['tiempo_2'])

# %%
def take_double_dots_out(x):
    x = str(x)
    if '..' in x:
        x = x.replace('..','.')
    return x

# %%
df['Norte'] = df['Norte'].apply(lambda x: take_double_dots_out(x))
df['Este'] = df['Este'].apply(lambda x: take_double_dots_out(x))
df['Norte'] = pd.to_numeric(df['Norte'].replace({'nan':None}))
df['Este'] = pd.to_numeric(df['Este'].replace({'nan':None}))

# %%
df
# Out:
#          Fase   Banco Tipo de tronadura Tipo Material   M Dominio Estructural  \
# 0     Stage 5  2930.0       Tronadura 1        Roca 1  L4             Noreste
# 1     Stage 4  2990.0       Tronadura 1        Roca 1  L4             Noreste
# 2     Stage 4  2930.0       Tronadura 1        Roca 1  L4             Noreste
# 1986  5.826775  14.724417  59951.200  90086.750  3470.0  13.0  14.0       7.0
# 1987  5.236223   8.188981  59943.227  89650.068  3470.0  13.0  14.0       7.0
# 1988  5.118113  10.866148        NaN        NaN     NaN   9.0  18.0       7.0
# 1989  6.023625  10.157486        NaN        NaN     NaN  13.0  14.0       7.0
# 1990  5.039373  12.795283  59190.000  91577.000  3395.0   9.0  18.0       7.0
# 1991  4.881892  10.669297  59582.000  91757.000  3395.0  18.0   9.0       7.0
# 1992  5.708665  12.874023  59217.000  91616.000  3395.0   9.0  18.0       7.0
# 1993  6.456696  10.866148  59523.000  91754.000  3395.0  18.0   9.0       7.0
# 1994  5.748035  13.031503  59602.000  91363.000  3380.0  13.0  14.0       5.0
# 1995  5.196853   9.094493  59319.000  91606.000  3395.0   9.0  18.0       7.0
# 1996  7.165358  13.503944  59485.000  91698.000  3395.0  18.0   9.0       7.0
# 1997  6.023625   8.779532  59205.000  91530.000  3395.0   9.0  18.0       7.0
# 1998  7.047248  10.314966  59440.000  91708.000  3395.0  18.0   9.0       7.0
# 2000  5.433074   9.566934  59161.000  91519.000  3395.0   9.0  18.0       7.0
# 2001  6.181106  14.291346  59428.000  91677.000  3395.0  18.0   9.0       7.0
#
#       tiempo_2
# 0        105.0
# 1        105.0
# 2        105.0
# 3         87.0
# 4         87.0
# 5        105.0
# 7         87.0
# 8         87.0
# 10       105.0
# 11       105.0
# 12        87.0
# 13        87.0
# 14        87.0
# 15        87.0
# 16       105.0
# 17       120.0
# 18        87.0
# 19        87.0
# 20       105.0
# 21        87.0
# 22       105.0
# 23        87.0
# 24        87.0
# 25         NaN
# 26        87.0
# 27       105.0
# 28        87.0
# 29       105.0
# 30        87.0
# 31        87.0
# ...        ...
# 1971     200.0
# 1972      36.0
# 1973     200.0
# 1974     165.0
# 1975     200.0
# 1976     165.0
# 1977     200.0
# 1978     165.0
# 1979     200.0
# 1980     165.0
# 1981      84.0
# 1982     165.0
# 1983      84.0
# 1984      84.0
# 1985     165.0
# 1986      84.0
# 1987      84.0
# 1988     165.0
# 1989      84.0
# 1990     165.0
# 1991     200.0
# 1992     165.0
# 1993     200.0
# 1994      84.0
# 1995     165.0
# 1996     200.0
# 1997     165.0
# 1998     200.0
# 2000     165.0
# 2001     200.0
#
# [1960 rows x 28 columns]

# %%
df.dtypes
# Out:
# Fase                            object
# Banco                          float64
# Tipo de tronadura               object
# Tipo Material                   object
# M                               object
# Dominio Estructural             object
# Diámetro                       float64
# BxS                             object
# Tiempo entre Pozos Filas ms     object
# Fc                             float64
# Tipo Explosivo                  object
# P10                            float64
# P20                            float64
# P30                            float64
# P40                            float64
# P50                            float64
# P60                            float64
# P70                            float64
# P80                            float64
# P90                            float64
# P100                           float64
# Este                           float64
# Norte                          float64
# Cota                           float64
# B                              float64
# S                              float64
# tiempo_1                       float64
# tiempo_2                       float64
# dtype: object

# %%
df.to_csv('data/data_fixed.csv', sep=';', index=False)
